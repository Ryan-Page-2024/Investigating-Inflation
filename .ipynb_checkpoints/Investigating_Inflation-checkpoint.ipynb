# %% [markdown]
# ## Project Overview

# %% [markdown]
# Between 2018 and 2026, the Global economy was hit by a sequence of distinct structural shocks including the COVID 19 pandemic, aggressive tariffs, and war abroad. I have chosen February 5th, 2018 to May 15th, 2026, because this marks when Jerome Powell served as chair on the Federal Reserve. <br><br> In this project, I will analyze the 10 Year Breakeven Inflation Rate (T10YIE) from **February 5th 2018** to **May 15th 2026** and in doing so:
# + Smooth noise and identify trends using **Moving Averages**
# + Measure the momentum and acceleration of **Year over Year changes**
# + Visualize volatility and extremes with **Bollinger Bands**
# + Research co-movements in brent crude oil prices with **Rolling Correlation**
# + Forecast long-term inflation sentiment using a **SARIMAX Model**

# %% [markdown]
# The T10YIE represents the market based estimate of average inflation over the next decade and is an advantageous metric to evaluate for several reasons, as it:
# + Informs us on whether we can expect the Federal Reserve to cut or raise interest rates in the near term
# + Measures whether markets price inflation as a persistent threat or a series of transitory shocks
# + Tracks real time investor reactions to geopolitical and trade tensions

# %% [markdown]
# Ultimately, this analysis will provide more insight into how inflation expectations have evolved through post-pandemic recovery and geopolitical conflicts.

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# In this section, I will perform an initial exploration of the 10-Year Breakeven Inflation Rate dataset that the Federal Reserve Bank of St. Louis makes available at <https://fred.stlouisfed.org/series/T10YIE>

# %% [markdown]
# ![Alt text](Images/fredgraph.png)

# %% [markdown]
# ### Load Libraries and Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import holidays
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('Data/T10YIE.xlsx', sheet_name=1)
df.head()
# Out:
#   observation_date  T10YIE
# 0       2018-02-05    2.10
# 1       2018-02-06    2.10
# 2       2018-02-07    2.10
# 3       2018-02-08    2.09
# 4       2018-02-09    2.05

# %% [markdown]
# ### Describe Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2160 entries, 0 to 2159
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   observation_date  2160 non-null   datetime64[ns]
#  1   T10YIE            2070 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 33.9 KB

# %%
df['T10YIE'].describe()
# Out:
# count    2070.000000
# mean        2.144763
# std         0.360505
# min         0.500000
# 25%         1.962500
# 50%         2.260000
# 75%         2.360000
# max         3.020000
# Name: T10YIE, dtype: float64

# %% [markdown]
# ### Check for Missing Values and Date Range

# %%
df.isna().sum()
# Out:
# observation_date     0
# T10YIE              90
# dtype: int64

# %%
us_holidays = holidays.UnitedStates(state='NJ') # New Jersey Recognizes All Federal Holidays, Including Good Friday
df['is_holiday'] = df['observation_date'].dt.date.apply(lambda x: x in us_holidays)
df[df['T10YIE'].isna()].groupby(['is_holiday'])['T10YIE'].size().reset_index(name='n_days')
# Out:
#    is_holiday  n_days
# 0       False       1
# 1        True      89

# %%
# December 5, 2018, was a National Day of Mourning for former President George H.W. Bush, resulting in a missing T10YIE observation
df.loc[(df['is_holiday']==False) &(df['T10YIE'].isna()), ]
# Out:
#     observation_date  T10YIE  is_holiday
# 217       2018-12-05     NaN       False

# %% [markdown]
# There's Missing Inflation Data on Federal Holidays, Which We Treat Using **Forward Filling**
# <br>&emsp; **Forward Filling:** Taking the Last Known Valid Observation Forward to Fill in Subsequent Missing Data

# %%
df['T10YIE'] = df['T10YIE'].ffill()
df = df.drop('is_holiday', axis=1).sort_values('observation_date')

# %% [markdown]
# ### Time Visualization

# %%
# 10-Year Breakeven Inflation Rate
plt.figure(figsize=(12,6))
plt.margins(x=0.0001)
plt.grid(alpha=0.3)
plt.title('10-Year Breakeven Inflation Rate', fontsize=12, fontweight='bold')
plt.plot(df['observation_date'], df['T10YIE'], color='#0073e6', linewidth=1)
plt.ylabel('Percent', labelpad=20)
plt.ylim(0, 3.5)
plt.xticks(fontsize=8)
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(bymonth=[1, 7]))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.show()

# %% [markdown]
# ## Background
# This plot shows the 10-Year Breakeven Inflation Rate and is covered below in detail:

# %% [markdown]
# + **2018-2019** <br> In the wake of the 2008 Financial Crisis, a distressed period from 2009 to 2016 beset with government bailouts, near-zero interest rates, and Quantitative Easing (QE), the Federal Reserve maintained highly accommodative monetary policies, explaining to some degree the elevated levels of inflation found at the start of the chart above.
# <br><br>
# To combat inflation, the Federal Reserve shifted towards stricter, hawkish policies such as reducing its purchases of government debt and raising interest rates to a range of 2.25% - 2.50%, which contributed to a noticeable decline in the T10YIE through 2018 and into much of 2019; however, this shift removed much of the liquidity that had previously boosted a strained economy.
# <br><br>
# When the Federal Reserve reduced its holdings of Treasury bills (T-bills) and mortgage backed securities, it took cash out of circulation by allowing more cash to remain on its balance sheet rather than being invested back into government debt and home loans. Because cash was taken out at unprecedented levels, this sparked concerns of a liquidity crisis as the financial system had grown increasingly dependent on this large outflow of cash into the economy that had allowed borrowing rates to remain suppressed.
# <br><br>
# By May 2019, the Federal Reserve slowed its pace in reducing the size of its balance sheet. Starting in October 2019, they began purchasing `$60B` in T-bills to address the liquidity crisis. These reactive cash injections focused on the short term flow of cash rather than long-term. This more favorable, dovish policy contributes to the moderate increase in the T10YIE observed in the tailend of 2019.
# <br>--
#
# + **2020-2021** <br>The COVID-19 pandemic caused a global shutdown, forcing inflation to drop suddenly in early 2020. March 2020 marks the lowest point, at `0.5`, that the T10YIE reached between 2018 and 2026, a drop not seen since the 2008 Financial Crisis. The Federal Reserve responded quickly to prevent a complete collapse of the financial system through several actions that consequently raised inflation aggressively.
# <br><br>
# Using two unscheduled emergency meetings, the Federal Reserve cut interest rates by 50 basis points (bps) on March 3rd, 2020 and again by 100bps on March 15th, 2020. These cuts brought interest rates to 0% - 0.25%. Alongside interest rate cuts, the Federal Reserve provided dovish forward guidance establishing that near-zero interest rates would be retained until the Federal Reserve was confident that the economy had weathered the shock of the pandemic.
# <br><br>
# Serving as a backstop to a faltering economy, the Central Bank deployed emergency tools under Section 13(3) of the Federal Reserve Act. To provide relief to a distressed country, the Federal Reserve provided extensive support including the creation of these institutions:
# <br><br>
# &nbsp;&nbsp;**Secondary Market Corporate Credit Facility (SMCCF):**
# <br>&nbsp;&nbsp;SMCCF provided `14.1B` in liquidity for outstanding corporate bonds between 5/15/2020 and 12/17/2021.
# <br><br>
# &nbsp;&nbsp;**Paycheck Protection Program Liquidity Facility (PPPLF):**
# <br>&nbsp;&nbsp;PPPLF extended `$800B` in credit to eligibile financial institutions between 4/13/2020 and 7/30/2021, ensuring lenders could fund loans for small businesses.
# <br><br>
# &nbsp;&nbsp;**Municipal Liquidity Facility (MLF):**
# <br>&nbsp;&nbsp;MLF provided `$17.5B` in support between 5/26/2020 and 12/31/2020 to state and local governments that had been facing immediate cash flow pressures.
# <br><br>
# &nbsp;&nbsp;**Main Street Lending Program (MSLP):**
# <br>&nbsp;&nbsp;MSLP supplied `$17.5B` between 7/6/2020 and 1/8/2021 to small and medium sized businesses that were in good standing before the pandemic.
# <br><br>
# Additionally, the Federal Reserve resumed QE at an accelerated rate from March 2020 to October 2021 before decelerating in November 2021 and tapering QE off entirely by March 2022. The bulk of this balance sheet expansion occurred between March 2020 and May 2020: three months that totaled `$3T`. When the Federal Reserve concluded its QE efforts, the balance sheet had expanded by `$5.3T` in aggregate.
# <br>--
#
# + **2022-2024** <br>Aggressive economic expansion following the COVID-19 pandemic led to the total assets held by the Federal Reserve exceeding `$8.965T`, the highest ever recorded balance in the entire Federal Reserve's history. When the Federal Reserve expanded its balance sheet, the move served as a signal to Congress that they can engage in elevated levels of discretionary spending. Consequently, the federal budget deficit, measuring the difference between what the U.S. government collects in revenue (receipts) and spends (outlays), increased by 33.21% from 2022 to 2024. This increase in government spending contributed to a rise in inflation as the T10YIE reached its peak of `3.02` on April 21st, 2022, and for the most part, hasn't fallen back to pre-pandemic levels.
# <br><br>
# The heightened level of inflation seen in the first half of 2022 was further exacerbated by the Russian invasion of Ukraine on February 24th, 2022, as oil prices rose on news of the outbreak. War meant not only human suffering but also economic pain. Russia accounted for roughly 11% of the world's oil production, and conflict caused brent crude to surge from around `$101` to as high as `$133` a barrel. Through releasing `180M` barrels of oil from the Strategic Petroleum Reserve (SPR), the United States helped drive the cost of oil down to stable levels by the end of 2022. With oil falling in price, inflation declined from a four decade high by the end of 2022.
# <br><br>
# To help rein in inflation, the Federal Reserve quickly raised interest rates and resumed Quantitative Tightening (QT) by allowing more cash to remain on its balance sheet rather than being reinvested into the economy. Interest rate hikes were announced from March 17th, 2022 through July 27th, 2023 by Jerome Powell after the Federal Open Markets Committee (FOMC) voted overwhelmingly in favor of raising rates. The near-zero interest rates that had fueled the United States economy were replaced with rates as high as 5.25% - 5.50%, lending conditions tightened, and the cost of doing business for many significantly increased. These fiscal positions helped moderate inflation across 2023 - 2024, and through policies like the CHIPS and Sciences act, the United States supply chain regained some stability lost during the COVID-19 pandemic. However, firms also began to look for ways to cut costs and often did so through layoffs.
# <br><br>
# Significant increases in layoffs coincided with the emergence and continued development of artificial intelligence (AI). AI, quantum computing, and robotics, among other areas of research, gained `$200B` in public funding through the enactment of the CHIPS and Science Act on August 9th, 2022. Before Google's Gemini and Anthropic's Claude models, OpenAI launched ChatGPT as a non-profit organization on November 30th, 2022 with the mission to ensure that artificial general intelligence benefits all of humanity. Questionable progress has been made towards that goal, as the organization transitioned into a 'capped-profit' structure and focused heavily on commercial licensing deals, leading to internal conflicts over whether the drive for revenue has compromised its original commitment to the greater good of humanity. From 2022 to 2024, global corporate investment into AI exceeded `$700B`, showing no signs of slowing down in 2025 and 2026. Meanwhile, layoffs from 2022 to 2024 surpassed `1.84M`. The Federal Reserve responded to this downturn in employment by cutting interest rates by 25bps September 18th, 2024 through December 18th, 2024, lowering rates to 4.25% - 4.50%. This decrease in interest rates can help explain the increase in the T10YIE observed in the second half of 2024.
# <br>--
# + **2025-2026**<br>
# Continuing into 2025, the T10YIE hovered around `2.4` in the first quarter before dropping down to `2.29` by mid March. A noticeable driver in the decline of the T10YIE was the decrease in energy costs. From January 17th, 2025 - March 2nd, 2026, brent crude oil prices have remained, for the most part, below `$80` and as low as `$60` a barrel. This is due to the United States producing record levels of energy in 2025, with offshore oil production totaling over `714M` barrels, the highest annual output on record. Even though there were numerous initiatives aimed at lowering Year-over-Year (YoY) changes in the price of oil alongside prescription drugs, automobiles, and various other goods, the net price consumers are paying has increased. Further, the T10YIE has remained elevated and the Federal Reserve has found excess inflation can be explained by the pass through of tariffs. Though tariffs had a somewhat muted effect on the T10YIE due, in large part, to the frequent changes in the way they've been implemented.
# <br><br>
# On April 2nd, 2025, new tariffs were announced under the International Emergency Economic Powers Act (IEEPA), with rates ranging from 10% to as high as 50%. These IEEPA rates sparked widespread confusion and outrage, as they were much higher than anticipated. While the rationale provided for their severity was that these were reciprocal tariffs, the formula used to arrive at these punitive levels had reflected the bilateral trade deficit that the United States held with each trading partner. A week later these IEEPA tariffs were largely put on hold, save for the significantly elevated tariffs on China that were raised to 145% and retained until May, 14th, 2025 when both sides finally agreed to a temporary pause. These sweeping tariffs with China and many other major trading partners had resumed again on August 7th, 2025 at negotiated rates. These IEEPA tariffs were in place until February 20th, 2026 when the Supreme Court ruled them unconstitutional in Learning Resources, Inc. v. Trump and the U.S. Court of International Trade ordered that the `$166B` garnered through IEEPA tariffs be refunded. Following the Supreme Court's ruling, the administration invoked Section 122 of the Trade Act of 1974 to implement a 10% global surcharge. These specific tariffs have an expiration date of July 24th, 2026. If a trade deficit with partner nations persists, then the administration may levy more permanent duties on imported goods; however, the trade deficit continues to shrink.
# <br><br>
# Data from the Bureau of Economic Analysis (BEA) and the Joint Economic Committee (JEC) indicates that the Annual Goods and Services deficit shrank from `$903.5B` in 2024 to `$901.5B` in 2025. This downward trend accelerated into 2026. During the first two months of the year, the deficit fell by `$136.1B`, representing a `54.8%` drop compared to the same period in 2025. This shift stems from a `$62.6B` (`11.3%`) surge in exports, with key contributors including industrial supplies, non-monetary gold, and natural gas. The latter had experienced significant momentum as global markets prioritized secure and stable energy sources in the midst of the Iran War. A global energy crisis due to the closure of the Strait of Hormuz had driven the price of oil to the highest point it has been at since the Russian invasion of the Ukraine. This waterway is a critical chokepoint, as approximately one fifth of global oil consumption passes through it daily. The tension present in the Middle East has driven an increased global reliance on the United States for energy. This tension is reflected in the T10YIE, as the metric continues to increase towards the end of the chart.
# <br><br>
# As the Federal Reserve balances its dual mandate of price stability and maximum employment, persistent inflation has complicated the trajectory for interest rates and balance sheet management. Following 25bps cuts in September, October, and December of 2025, the federal funds rate reached a range of 3.50% - 3.75%. While the reductions were intended to support growth, the inflationary pressures caused by the energy crisis had prompted a continued pause in further adjustments.
# <br><br>
# Unfortunately, the uncertainty from the Iran War is widely expected to lead to an increase in layoffs that will eventually prompt the Federal Reserve to continue to lower interest rates when the price of oil drops. This continued reduction is made more obvious, because Kevin Warsh, a known proponent of rate cuts, has been confirmed as the new chair of the Federal Reserve. It is believed that Kevin Warsh will shrink the Federal Reserve's balance sheet in an effort to allow for significant reductions in interest rates. In my own opinion, I believe the T10YIE will drop significantly in the second half of 2026, as oil drops in price, layoffs rise, and tariffs expire.
# <br>--

# %% [markdown]
# ## Trend Analysis
# This section applies trend analysis techniques to extract nuanced insights from the time series data.

# %% [markdown]
# ### Moving Averages
# Moving averages smooth short-term fluctuations and help reveal underlying trends. They are a simple yet effective tool in time series analysis.
# <br>
# A **30-Day moving average** highlights recent shifts, while a **90-day moving average** captures broader, more structural trends.
# <br>
# **Crossovers** between short and long-term averages often act as early indicators of **uptrends or downtrends**.

# %% [markdown]
# #### Interpretation Guide
# Moving averages effectively filter out daily noise to reveal the core direction inflation is headed. Different windows provide distinct insights into market expectations:
# <br><br>
# **Short-Term Moving Average (30 Days):** <br>
# These averages are designed to identify immediate fluctuations and responsive inflationary pressures.
# <br><br>
# **Long-Term Moving Average (90 Days):** <br>
# These averages focus on structural shifts and sticky inflation.
# <br><br>
# **Crossover Event:** <br>
# When the short-term moving averages rise above the long-term moving average, it indicates an upward trajectory for inflation.

# %% [markdown]
# #### Implementation and Visualization

# %%
# Moving Averages
df['MA_30'] = df['T10YIE'].rolling(window=30).mean()
df['MA_90'] = df['T10YIE'].rolling(window=90).mean()

# Breakeven Inflation Rate with Highlighted Phases
plt.figure(figsize=(12,6))
plt.margins(x=0.0001)
plt.grid(alpha=0.3)
plt.title('Breakeven Inflation Rate with Highlighted Phases', fontsize=12, fontweight='bold')
plt.plot(df['observation_date'], df['T10YIE'], label='Daily Rate', alpha=0.45, color='#48494B', linewidth=1)
plt.plot(df['observation_date'], df['MA_30'], label=('30-Day Moving Average'), color='#DC143C', linewidth=1)
plt.plot(df['observation_date'], df['MA_90'], label=('90-Day Moving Average'), color='#000080', linewidth=1)
plt.ylabel('Inflation Rate (%)', labelpad=20)
plt.xlabel('Date', labelpad=20)
plt.ylim(0, 3.5)
plt.xticks(fontsize=8)
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(bymonth=[1, 7]))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# Create Phases
plt.axvspan(pd.to_datetime('2018-02-05'), pd.to_datetime('2019-12-31'), 
            color='#DBF9DB', alpha=0.6, label='Phase 1: 2018-2019')

plt.axvspan(pd.to_datetime('2020-01-01'), pd.to_datetime('2021-12-31'), 
            color='#FFE0B2', alpha=0.6, label='Phase 2: 2020-2021')

plt.axvspan(pd.to_datetime('2022-01-01'), pd.to_datetime('2024-12-31'), 
            color='#B2EBF2', alpha=0.6, label='Phase 3: 2022-2024')

plt.axvspan(pd.to_datetime('2025-01-01'), pd.to_datetime('2026-05-15'), 
            color='#F2D1F2', alpha=0.6, label='Phase 4: 2025-2026')

# Ancillary 
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Interpretation
# The moving averages reveal distinct patterns across four distinct phases of inflation expectations:

# %% [markdown]
# + **Phase 1: 2018-2019** <br>
# The 30-Day Moving Average came down quicker than the 90-Day Moving Average, as monetary policies pushed inflation expectations down and short-term fluctuations acted quicker than long-term. The 30-Day Moving Average rose above the 90-Day Moving Average in 2019 twice, indicating two crossover events. This inversion means the market expected high inflation in the short term, but believed inflation would cool down eventually.<br>
#
# <table>
# <table border="1" style="text-align: center;">
#   <tr style="background-color: #dbf9db; color: black;">
#     <th>Key</th>
#     <th>Range</th>
#     <th>Value (%)</th>
#   </tr>
#   <tr>
#     <td style="background-color: #c2c2c3;"></td>
#     <td>Daily Inflation Range</td>
#     <td>1.48 - 2.18</td>
#   </tr>
#   <tr>
#     <td style="background-color: #dc143c;"></td>
#     <td>30-Day Moving Average Range</td>
#     <td>1.56 - 2.16</td>
#   </tr>
#   <tr>
#     <td style="background-color: #000080;"></td>
#     <td>90-Day Moving Average Range</td>
#     <td>1.59 - 2.13</td>
#   </tr>
# </table>
#
# + **Phase 2: 2020-2021** <br>
# Following a brief increase in inflation expectations, the 30-Day Moving Average dropped sharply during the outbreak of the COVID-19 pandemic. This initial decline acts as a precursor for the 90-Day Moving Average, which follows a similar path, albeit less intense. This lagging response produced a crossover event midway through 2020 where the 30-Day Moving Average rose above the 90-Day Moving Average. The 30-Day Moving Average remained elevated above the 90-Day Moving Average for much of 2020 and 2021. This trend shows how prices in the short-term were expected to rise rapidly and remain relatively unchanged in the near term, as the 90-Day Moving Average followed this rise in momentum.<br>
#
# <table>
# <table border="1" style="text-align: center;">
#   <tr style="background-color: #ffe0b2; color: black;">
#     <th>Key</th>
#     <th>Range</th>
#     <th>Value (%)</th>
#   </tr>
#   <tr>
#     <td style="background-color: #c2c2c3;"></td>
#     <td>Daily Inflation Range</td>
#     <td>0.5 - 2.76</td>
#   </tr>
#   <tr>
#     <td style="background-color: #dc143c;"></td>
#     <td>30-Day Moving Average Range</td>
#     <td>0.98 - 2.62</td>
#   </tr>
#   <tr>
#     <td style="background-color: #000080;"></td>
#     <td>90-Day Moving Average Range</td>
#     <td>1.13 - 2.46</td>
#   </tr>
# </table>
#
#
# + **Phase 3: 2022-2024** <br>
# Stemming from dovish monetary policy, the 30-Day Moving Average hit a four decade high inflection point, experiencing a short lived crossover event that presaged the 90-Day Moving Average peak. From 2022 through 2024, there are six separate crossover events. This frequent recurrence is representative of the sticky inflation that plagued this period.<br>
#
# <table>
# <table border="1" style="text-align: center;">
#   <tr style="background-color: #b2ebf2; color: black;">
#     <th>Key</th>
#     <th>Range</th>
#     <th>Value (%)</th>
#   </tr>
#   <tr>
#     <td style="background-color: #c2c2c3;"></td>
#     <td>Daily Inflation Range</td>
#     <td>2.02 - 3.02</td>
#   </tr>
#   <tr>
#     <td style="background-color: #dc143c;"></td>
#     <td>30-Day Moving Average Range</td>
#     <td>2.09 - 2.89</td>
#   </tr>
#   <tr>
#     <td style="background-color: #000080;"></td>
#     <td>90-Day Moving Average Range</td>
#     <td>2.19 - 2.76</td>
#   </tr>
# </table>
#
# + **Phase 4: 2025-2026** <br>
# In 2025 and 2026, the 30-Day Moving Average continued to crossover the 90-Day Moving Average frequently. This time period continued to be inflicted by the same sticky inflation that the previous phase had endured. Similarly, the expected inflation rate remained elevated.<br>
#
# <table>
# <table border="1" style="text-align: center;">
#   <tr style="background-color: #f2d1f2; color: black;">
#     <th>Key</th>
#     <th>Range</th>
#     <th>Value (%)</th>
#   </tr>
#   <tr>
#     <td style="background-color: #c2c2c3;"></td>
#     <td>Daily Inflation Range</td>
#     <td>2.17 - 2.48</td>
#   </tr>
#   <tr>
#     <td style="background-color: #dc143c;"></td>
#     <td>30-Day Moving Average Range</td>
#     <td>2.24 - 2.43</td>
#   </tr>
#   <tr>
#     <td style="background-color: #000080;"></td>
#     <td>90-Day Moving Average Range</td>
#     <td>2.26 - 2.36</td>
#   </tr>
# </table>

# %% [markdown]
# ### Year-over-Year Change
# The Year-over-Year (YoY) technique measures the momentum of inflation sentiment by assessing how today's inflation expectations compare to the same day one year ago. This technique helps filter out daily noise and seasonality to reveal general market expectations on whether inflation is accelerating or cooling. Fundamentally, YoY changes indicate both directional speed and level of expected inflation 10 years in the future.

# %% [markdown]
# #### Interpretation Guide
# + **Positive Change:**
# <br>
# Positive values indicate expectations that inflation will rise
# <br><br>
# + **Negative Change:**
# <br>
# Negative values point to anticipated declines in inflation
# <br><br>
# + **Near Zero Change:**
# <br>
# Values near zero represent negligible change

# %% [markdown]
# #### How Are Year-over-Year Changes Measured?
# The following formula is used to compute Year-over-Year change in the T10YIE:
# <br>
#
# **Formula:** <br>
# $$\text{YoY Change} = \text{Current Value} - \text{Value 365 Days Ago}$$

# %% [markdown]
# #### Implementation and Visualization

# %%
# Inflation Rate and Year-over-Year Change
df['T10YIE'] = df['T10YIE'].ffill()
df_daily = df.set_index('observation_date')[['T10YIE']].resample('D').ffill()
df_daily['YoY_Change_True'] = df_daily['T10YIE'].diff(365)
df['YoY_Change'] = df['observation_date'].map(df_daily['YoY_Change_True'])

# Define Direction
df['Direction'] = np.nan
df.loc[df['YoY_Change'] < 0, 'Direction'] = 'Falling'
df.loc[df['YoY_Change'] > 0, 'Direction'] = 'Rising'
df['Direction'] = df['Direction'].ffill().bfill()

# Exclude Because No Year-over-Year Change
df_valid = df.dropna(subset=["YoY_Change"]).copy()

# Create Unique IDs for Each Continuous Block
df_valid['regime_id'] = (df_valid['Direction'] != df_valid['Direction'].shift()).cumsum()

# Aggregate to Find Start, End, and Direction of Each Zone
zones = (
    df_valid.groupby('regime_id')
    .agg(
        start=('observation_date', 'min'),
        end=('observation_date', 'max'),
        direction=('Direction', 'first'),
    )
    .reset_index()
)

# Create Figure with Shared Axis
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(16, 10), sharex=True)

# 10-Year Breakeven Rate
ax1.grid(alpha=0.3)
ax1.set_title('10-Year Breakeven Inflation Rate', fontsize=12, fontweight='bold')
ax1.plot(df['observation_date'], df['T10YIE'], color='#0073e6', linewidth=1)
ax1.set_ylabel('Inflation Rate (%)', labelpad=20)

# YoY Change in Inflation Expectations
ax2.grid(alpha=0.3)
ax2.set_title('Year-over-Year Change in Inflation Expectations', fontsize=12, fontweight='bold')
ax2.plot(df['observation_date'], df['YoY_Change'], color='#0073e6', linewidth=1)
ax2.set_ylabel('YoY Change (%)', labelpad=12)
ax2.set_xlabel('Date', labelpad=20)
ax2.xaxis.set_major_locator(mdates.MonthLocator(bymonth=[1, 7]))
ax2.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
ax2.axhline(y=0, color='black', linestyle='-', linewidth=1, alpha=0.7)
ax2.fill_between(df['observation_date'], df['YoY_Change'], 0, where=(df['YoY_Change'] > 0), color='#90EE90', label='Rising YoY')
ax2.fill_between(df['observation_date'], df['YoY_Change'], 0, where=(df['YoY_Change'] <= 0), color='#F08080', label='Falling YoY')

# Create Background
color_map = {'Rising': '#90EE90', 'Falling': '#F08080'}
for _, zone in zones.iterrows():
    current_color = color_map.get(zone['direction'])
    if current_color:
        ax1.axvspan(zone['start'], zone['end'], color=current_color, alpha=0.3)
        ax2.axvspan(zone['start'], zone['end'], color=current_color, alpha=0.3)

# Ancillary
ax2.legend(loc='lower left')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Interpretation
# This chart compares the 10-Year Breakeven Inflation Rate (top chart) with the Year-over-Year Change in inflation expectations (bottom chart), capturing market derived long-term expectations and underlying momentum.

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;**Phase 1: February 5th, 2019 - August 10th, 2020** (Duration: $553$ days) <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;We start measuring Year-over-Year Change in inflation expectations on February 5th, 2019 as this is one year after the project’s starting point of February 5th,<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;2018.<br>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;In this phase, Year-over-Year Change is generally negative, as the market expected inflation to fall in the long-term. The lowest point in inflation expectations was <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;reached on March 19th, 2020 with a negative change of -1.46 and a T10YIE of 0.50.<br>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;There are points that indicate a rise in inflation expectations occurring around early 2020, as well as in the third quarter of 2020. Specifically, on August 10th, 2020 <br> &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;there is a near zero Year-over-Year Change of -0.05 when T10YIE hit 1.61, marking the last point of this extended contraction.<br>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Here are a few important metrics to help characterize this phase:<br>
#
# <table>
# <table border="1" style="text-align: center;">
#   <tr style="background-color: #f08080; color: black;">
#     <th>Metric</th>
#     <th>T10YIE (%)</th>
#     <th>Year-over-Year Change (%)</th>
#   </tr>
#   <tr>
#     <td>Range</td>
#     <td>0.50 - 1.98</td>
#     <td>-1.46 - 0.10</td>
#   </tr>
#   <tr>
#     <td>Mean</td>
#     <td>1.57</td>
#     <td>-0.40</td>
#   </tr>
#   <tr>
#     <td>Median</td>
#     <td>1.63</td>
#     <td>-0.36</td>
#   </tr>
# </table>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;**Phase 2: August 11th, 2020 - September 23rd, 2022** (Duration: $774$ days) <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Following an extended contraction in inflation expectations, Year-over-Year Change rose quickly from August 11th, 2020 until there was a pullback in the third<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;quarter of 2022.<br>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Through this phase, Year-over-Year Change remained mostly positive, as the market believed that inflation would rise in the long-term. Inflation expectations hit<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;a 40 year peak on March 19th, 2021 with a positive change of 1.81 and a T10YIE of 2.31.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;There are a couple of moments in this phase where inflation expectations fell, such as in late 2020 and in the second half of 2022. While some of those moments<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;when inflation appeared to be contracting were short-lived and sporadic, by the third quarter of 2022 there was more market consensus that long-term inflation <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;expectations would moderate.<br>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Here again are some important metrics that provide more context for this phase:<br>
#
# <table>
# <table border="1" style="text-align: center;">
#   <tr style="background-color: #90ee90; color: black;">
#     <th>Metric</th>
#     <th>T10YIE (%)</th>
#     <th>Year-over-Year Change (%)</th>
#   </tr>
#   <tr>
#     <td>Range</td>
#     <td>1.58 - 3.02</td>
#     <td>-0.05 - 1.81</td>
#   </tr>
#   <tr>
#     <td>Mean</td>
#     <td>2.32</td>
#     <td>0.53</td>
#   </tr>
#   <tr>
#     <td>Median</td>
#     <td>2.38</td>
#     <td>0.48</td>
#   </tr>
# </table>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;**Phase 3: September 26th, 2022 - March 13th, 2024** (Duration: $535$ days) <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Inflation expectations continued to decline from a 40 year peak, with Year-over-Year Changes falling in relative terms by September 26th, 2022;<br> &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;only, this phase of contraction was marred by inflation that seemed to stick around.<br>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Year-over-Year Change in this period fell to as low as -0.81 when T10YIE hit 2.1 on March 17th, 2023. This T10YIE remained above the max value of 1.98 that was <br> &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;experienced in Phase 1, highlighting how inflation expectations can fall in Year-over-Year terms but remain elevated in a more general sense.<br>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Inflation expectations grew during two key periods. From September 26th, 2023 to October 13th, 2023, the positive change in Year-over-Year inflation<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;expectations ranged from 0 to 0.2, while the T10YIE range was between 2.31 and 2.39 before coming back down.<br>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Similarly, during the second growth period from January 12th, 2024 to January 25th, 2025 Year-over-Year expectations spanned 0 - 0.22 and the T10YIE ranged<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;2.27 - 2.34 prior to reversing course. <br>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;The metrics below provide more background into this broader phase of contracting inflation expectations:<br>
#
# <table>
# <table border="1" style="text-align: center;">
#   <tr style="background-color: #f08080; color: black;">
#     <th>Metric</th>
#     <th>T10YIE (%)</th>
#     <th>Year-over-Year Change (%)</th>
#   </tr>
#   <tr>
#     <td>Range</td>
#     <td>2.1 - 2.59</td>
#     <td>-0.81 - 0.22</td>
#   </tr>
#   <tr>
#     <td>Mean</td>
#     <td>2.29</td>
#     <td>-0.20</td>
#   </tr>
#   <tr>
#     <td>Median</td>
#     <td>2.28</td>
#     <td>-0.13</td>
#   </tr>
# </table>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;**Phase 4: March 14th, 2024 - May 15th, 2026** (Duration: $793$ days) <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;In starting to evaluate this phase, I want to begin by highlighting how there are a mixture of times when the general market expected long-term inflation to<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;rise only to seemingly reverse course within the next few months. These sudden changes in expectations are representative of uncertainty plaguing trade policy<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;alongside elevated geopolitical tensions. Here’s a high-level overview for each fluctuation:<br>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;March 14th, 2024 - July 18th, 2024:<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Year-over-Year Inflation Expectations Range: -0.04 - 0.23<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;T10YIE Range: 2.17 - 2.43
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;July 19th, 2024 - November 7th, 2024:<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Year-over-Year Inflation Expectations Range: -0.33 - 0.01<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;T10YIE Range: 2.02 - 2.38
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;November 8th, 2024 - March 31st, 2025:<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Year-over-Year Inflation Expectations Range: -0.03 - 0.24<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;T10YIE Range: 2.24 - 2.46
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;April 1st, 2025 - June 11th, 2025:<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Year-over-Year Inflation Expectations Range: -0.26 - 0.04<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;T10YIE Range: 2.17 - 2.37
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;June 12th, 2025 - October 9th, 2025:<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Year-over-Year Inflation Expectations Range: -0.03 - 0.34<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;T10YIE Range: 2.25 - 2.45
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;October 10th, 2025 - March 5th, 2026:<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Year-over-Year Inflation Expectations Range: -0.17 - 0.03<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;T10YIE Range: 2.22 - 2.36
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;March 6th, 2026 - May 15th, 2026:<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Year-over-Year Inflation Expectations Range: -0.08 - 0.23<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;T10YIE Range: 2.30 - 2.50<br>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;The following metrics provide an overview of this phase of rapid change and ultimately point to a recent rise in long-term inflation expectations, as <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Year-over-Year Change is positive on average.<br>
#
# <table>
# <table border="1" style="text-align: center;">
#   <tr style="background-color: #90ee90; color: black;">
#     <th>Metric</th>
#     <th>T10YIE (%)</th>
#     <th>Year-over-Year Change (%)</th>
#   </tr>
#   <tr>
#     <td>Range</td>
#     <td>2.02 - 2.50</td>
#     <td>-0.33 - 0.34</td>
#   </tr>
#   <tr>
#     <td>Mean</td>
#     <td>2.31</td>
#     <td>0.02</td>
#   </tr>
#   <tr>
#     <td>Median</td>
#     <td>2.32</td>
#     <td>0.03</td>
#   </tr>
# </table>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;This Year-over-Year Change in Inflation Expectations analysis has captured a general trend where a period of rising inflation is followed by a cyclical drop in<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;inflation and, although it isn’t guaranteed, I believe that inflation will fall in the second half of 2026.

# %% [markdown]
# ### Bollinger Bands
# Bollinger Bands use standard deviation to establish upper and lower boundaries around a moving average. The bands expand during volatile periods and contract when market uncertainty calms down. In my analysis, Bollinger Bands reveal when inflation expectations are within normal historical ranges (inside bands), as well as when inflation expectations are reaching new, outlier levels (outside bands).<br><br>
# When the rate touches the upper band, it signals unusually high expectations, while touching the lower band indicates unusually low expectations. It is important to note that roughly **88% of the data** falls within these boundaries.
# <br><br>**Formulas:**<br>
# $$\text{Middle Band} = \text{30-Day Moving Average}$$
# $$\text{Upper Band} = \text{Middle Band} + \text{(2 x Standard Deviation)}$$
# $$\text{Lower Band} = \text{Middle Band} - \text{(2 x Standard Deviation)}$$

# %% [markdown]
# #### Interpretation Guide
# The goal of using Bollinger Bands is to measure volatility and identify periods when values deviate significantly from the average. In the context of the 10-Year Breakeven Inflation Rate (T10YIE):<br>
#
# + When volatility rises, the bands widen and show how uncertain the market is regarding long-term inflation
# + When volatility falls, the bands tighten, signaling more market consensus in general inflation expectations
# + Points outside of the bands represent extreme behavior, while values within are considered normal
# + Upper Band breaches indicate periods of strong inflation sentiment or panic
# + Lower Band breaches suggest unusually low inflation or deflation

# %% [markdown]
# #### Implementation and Visualization

# %%
# Bollinger Bands
df['Middle_Band'] = df['T10YIE'].rolling(window=30).mean()
df['Standard_Deviation'] = df['T10YIE'].rolling(window=30).std()
df['Upper_Band'] = df['Middle_Band'] + (2 * df['Standard_Deviation'])
df['Lower_Band'] = df['Middle_Band'] - (2 * df['Standard_Deviation'])
df['Bandwidth'] = df['Upper_Band'] - df['Lower_Band']

# 10-Year Breakeven Inflation Rate with Bollinger Bands
plt.figure(figsize=(12, 6))
plt.margins(x=0.0001)
plt.grid(alpha=0.3)
plt.title('10-Year Breakeven Inflation Rate with Bollinger Bands', fontsize=12, fontweight='bold')
plt.plot(df['observation_date'], df['T10YIE'], label='Daily Rate', color='#0073e6', linewidth=1)
plt.plot(df['observation_date'], df['Middle_Band'], label='30-Day MA', color='#DC143C', linewidth=1)
plt.plot(df['observation_date'], df['Upper_Band'], label='Upper Band', color='#5A6A85', linewidth=1, linestyle='--')
plt.plot(df['observation_date'], df['Lower_Band'], label='Lower Band', color='#1E293B', linewidth=1, linestyle='--')
plt.fill_between(df['observation_date'], df['Upper_Band'], df['Lower_Band'], alpha=0.1, color='#808080')
plt.ylabel('Inflation Rate (%)', labelpad=20)
plt.xlabel('Date', labelpad=20)
plt.ylim(0, 3.5)
plt.xticks(fontsize=8)
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(bymonth=[1, 7]))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# Identify Points Daily Rate Breaches Upper and Lower Band
df['Upper_Breach'] = df['T10YIE'] > df['Upper_Band']
df['Lower_Breach'] = df['T10YIE'] < df['Lower_Band']

# Plotting Breach Points as Scatter Plots
plt.scatter(df[df['Upper_Breach']]['observation_date'], df[df['Upper_Breach']]['T10YIE'], 
            color='#006400', marker='.', s=15, label='Upper Breach', zorder=5)

plt.scatter(df[df['Lower_Breach']]['observation_date'], df[df['Lower_Breach']]['T10YIE'], 
            color='#8B0000', marker='.', s=15, label='Lower Breach', zorder=5)

# Identify Periods of Band Expansion and Contraction
avg_bandwidth = df['Bandwidth'].mean()
df['Band_Expansion'] = df['Bandwidth'] > (2 * avg_bandwidth)
df['Band_Contraction'] = df['Bandwidth'] < (avg_bandwidth / 2)
plt.axvspan(np.nan, np.nan, color='#90EE90', alpha=0.4, label='Band Expansion')
plt.axvspan(np.nan, np.nan, color='#F08080', alpha=0.4, label='Band Contraction')

# Graph Band Expansion and Contraction
for i in range(1, len(df)):
    start_date = df['observation_date'].iloc[i-1]
    end_date = df['observation_date'].iloc[i]
    
    if df['Band_Expansion'].iloc[i]:
        plt.axvspan(start_date, end_date, color='#90EE90', alpha=0.4)
    elif df['Band_Contraction'].iloc[i]:
        plt.axvspan(start_date, end_date, color='#F08080', alpha=0.4)

plt.legend(loc='lower right')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Interpretation
# Using the Bollinger Bands technique, observation dates with extreme inflation expectations are isolated below, with cell shading indicating whether breach happened during a period of band expansion (**green**) or contraction (**red**): <br>
#
# <table style="width: 100%; table-layout: fixed;">
# <tr>
# <th colspan="10" style="background-color: #006400; color: white; font-size: 1.1em; padding: 8px; text-align: center;">
# Dates of Upper Band Breaches
# </th>
# </tr>
# <tr>
# <td colspan="10" style="background-color: #f2f2f2; font-size: 1.1em; padding: 8px; text-align: center;">
# These <b>146 dates</b> represent <b>~6.8% of the 2,160 collected</b>, marking periods when inflation expectations broke through the upper band.
# </td>
# </tr>
# <tr>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">4/17/2018</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">4/18/2018</td>
# <td style="text-align: center;">4/19/2018</td>
# <td style="text-align: center;">4/20/2018</td>
# <td style="text-align: center;">4/23/2018</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">9/18/2018</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">9/19/2018</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">9/20/2018</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">9/21/2018</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">9/24/2018</td>
# </tr>
# <tr>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">9/25/2018</td>
# <td style="text-align: center;">2/21/2019</td>
# <td style="text-align: center;">2/28/2019</td>
# <td style="text-align: center;">3/1/2019</td>
# <td style="text-align: center;">7/16/2019</td>
# <td style="text-align: center;">9/13/2019</td>
# <td style="text-align: center;">11/5/2019</td>
# <td style="text-align: center;">11/8/2019</td>
# <td style="text-align: center;">12/17/2019</td>
# <td style="text-align: center;">12/18/2019</td>
# </tr>
# <tr>
# <td style="text-align: center;">12/19/2019</td>
# <td style="text-align: center;">6/3/2020</td>
# <td style="text-align: center;">6/4/2020</td>
# <td style="text-align: center;">6/5/2020</td>
# <td style="text-align: center;">6/8/2020</td>
# <td style="text-align: center;">6/22/2020</td>
# <td style="text-align: center;">6/23/2020</td>
# <td style="text-align: center;">7/6/2020</td>
# <td style="text-align: center;">8/3/2020</td>
# <td style="text-align: center;">8/5/2020</td>
# </tr>
# <tr>
# <td style="text-align: center;">8/6/2020</td>
# <td style="text-align: center;">8/12/2020</td>
# <td style="text-align: center;">8/31/2020</td>
# <td style="text-align: center;">12/1/2020</td>
# <td style="text-align: center;">12/2/2020</td>
# <td style="text-align: center;">12/3/2020</td>
# <td style="text-align: center;">12/4/2020</td>
# <td style="text-align: center;">12/7/2020</td>
# <td style="text-align: center;">12/8/2020</td>
# <td style="text-align: center;">12/9/2020</td>
# </tr>
# <tr>
# <td style="text-align: center;">1/7/2021</td>
# <td style="text-align: center;">2/3/2021</td>
# <td style="text-align: center;">2/5/2021</td>
# <td style="text-align: center;">2/8/2021</td>
# <td style="text-align: center;">3/10/2021</td>
# <td style="text-align: center;">3/11/2021</td>
# <td style="text-align: center;">3/16/2021</td>
# <td style="text-align: center;">3/17/2021</td>
# <td style="text-align: center;">3/22/2021</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">4/27/2021</td>
# </tr>
# <tr>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">4/28/2021</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">4/29/2021</td>
# <td style="text-align: center;">4/30/2021</td>
# <td style="text-align: center;">5/3/2021</td>
# <td style="text-align: center;">5/5/2021</td>
# <td style="text-align: center;">5/6/2021</td>
# <td style="text-align: center;">5/7/2021</td>
# <td style="text-align: center;">5/10/2021</td>
# <td style="text-align: center;">5/11/2021</td>
# <td style="text-align: center;">5/12/2021</td>
# </tr>
# <tr>
# <td style="text-align: center;">7/26/2021</td>
# <td style="text-align: center;">7/28/2021</td>
# <td style="text-align: center;">7/29/2021</td>
# <td style="text-align: center;">10/5/2021</td>
# <td style="text-align: center;">10/7/2021</td>
# <td style="text-align: center;">10/8/2021</td>
# <td style="text-align: center;">10/11/2021</td>
# <td style="text-align: center;">10/13/2021</td>
# <td style="text-align: center;">10/15/2021</td>
# <td style="text-align: center;">10/21/2021</td>
# </tr>
# <tr>
# <td style="text-align: center;">10/22/2021</td>
# <td style="background-color: #dbf9d6; font-weight: bold; text-align: center;">10/26/2021</td>
# <td style="text-align: center;">11/15/2021</td>
# <td style="text-align: center;">2/23/2022</td>
# <td style="text-align: center;">2/24/2022</td>
# <td style="text-align: center;">2/25/2022</td>
# <td style="text-align: center;">2/28/2022</td>
# <td style="text-align: center;">3/1/2022</td>
# <td style="text-align: center;">3/2/2022</td>
# <td style="text-align: center;">3/3/2022</td>
# </tr>
# <tr>
# <td style="text-align: center;">3/4/2022</td>
# <td style="text-align: center;">3/7/2022</td>
# <td style="background-color: #dbf9d6; font-weight: bold; text-align: center;">3/8/2022</td>
# <td style="background-color: #dbf9d6; font-weight: bold; text-align: center;">3/9/2022</td>
# <td style="background-color: #dbf9d6; font-weight: bold; text-align: center;">3/10/2022</td>
# <td style="background-color: #dbf9d6; font-weight: bold; text-align: center;">3/11/2022</td>
# <td style="text-align: center;">4/21/2022</td>
# <td style="text-align: center;">8/24/2022</td>
# <td style="text-align: center;">10/24/2022</td>
# <td style="text-align: center;">2/21/2023</td>
# </tr>
# <tr>
# <td style="text-align: center;">3/2/2023</td>
# <td style="text-align: center;">3/3/2023</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">7/6/2023</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">7/7/2023</td>
# <td style="text-align: center;">7/20/2023</td>
# <td style="text-align: center;">7/21/2023</td>
# <td style="text-align: center;">7/24/2023</td>
# <td style="text-align: center;">7/25/2023</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">10/17/2023</td>
# <td style="text-align: center;">10/18/2023</td>
# </tr>
# <tr>
# <td style="text-align: center;">10/19/2023</td>
# <td style="text-align: center;">10/20/2023</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">1/12/2024</td>
# <td style="text-align: center;">1/15/2024</td>
# <td style="text-align: center;">1/16/2024</td>
# <td style="text-align: center;">1/17/2024</td>
# <td style="text-align: center;">1/18/2024</td>
# <td style="text-align: center;">1/19/2024</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">4/2/2024</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">4/5/2024</td>
# </tr>
# <tr>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">4/8/2024</td>
# <td style="text-align: center;">4/10/2024</td>
# <td style="text-align: center;">4/11/2024</td>
# <td style="text-align: center;">4/15/2024</td>
# <td style="text-align: center;">4/16/2024</td>
# <td style="text-align: center;">10/7/2024</td>
# <td style="text-align: center;">10/10/2024</td>
# <td style="text-align: center;">1/8/2025</td>
# <td style="text-align: center;">1/10/2025</td>
# <td style="text-align: center;">1/13/2025</td>
# </tr>
# <tr>
# <td style="text-align: center;">1/14/2025</td>
# <td style="text-align: center;">5/14/2025</td>
# <td style="text-align: center;">7/7/2025</td>
# <td style="text-align: center;">7/11/2025</td>
# <td style="text-align: center;">7/14/2025</td>
# <td style="text-align: center;">7/15/2025</td>
# <td style="text-align: center;">7/16/2025</td>
# <td style="text-align: center;">7/17/2025</td>
# <td style="text-align: center;">7/24/2025</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">1/6/2026</td>
# </tr>
# <tr>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">1/9/2026</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">1/12/2026</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">1/13/2026</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">1/16/2026</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">1/19/2026</td>
# <td style="text-align: center;">1/20/2026</td>
# <td style="text-align: center;">1/21/2026</td>
# <td style="text-align: center;">1/28/2026</td>
# <td style="text-align: center;">3/18/2026</td>
# <td style="text-align: center;">4/23/2026</td>
# </tr>
# <tr>
# <td style="text-align: center;">4/27/2026</td>
# <td style="text-align: center;">4/28/2026</td>
# <td style="text-align: center;">4/29/2026</td>
# <td style="text-align: center;">4/30/2026</td>
# <td style="text-align: center;">5/1/2026</td>
# <td style="text-align: center;">5/4/2026</td>
# </tr>
# </table>
#
# <table style="width: 100%; table-layout: fixed;">
# <tr>
# <th colspan="10" style="background-color: #8b0000; color: white; font-size: 1.1em; padding: 8px; text-align: center;">
# Dates of Upper Band Breaches
# </th>
# </tr>
# <tr>
# <td colspan="10" style="background-color: #f2f2f2; font-size: 1.1em; padding: 8px; text-align: center;">
# These <b>113 dates</b> represent <b>~5% of the 2,160 collected</b>, marking periods when inflation expectations fell below the lower band.
# </td>
# </tr>
# <tr>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">3/28/2018</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">5/24/2018</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">5/25/2018</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">5/28/2018</td>
# <td style="text-align: center;">5/29/2018</td>
# <td style="text-align: center;">5/30/2018</td>
# <td style="text-align: center;">5/31/2018</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">7/17/2018</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">7/18/2018</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">8/15/2018</td>
# </tr>
# <tr>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">8/20/2018</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">10/24/2018</td>
# <td style="text-align: center;">10/25/2018</td>
# <td style="text-align: center;">10/26/2018</td>
# <td style="text-align: center;">10/29/2018</td>
# <td style="text-align: center;">10/30/2018</td>
# <td style="text-align: center;">11/1/2018</td>
# <td style="text-align: center;">11/20/2018</td>
# <td style="text-align: center;">11/27/2018</td>
# <td style="text-align: center;">12/10/2018</td>
# </tr>
# <tr>
# <td style="text-align: center;">12/11/2018</td>
# <td style="text-align: center;">12/12/2018</td>
# <td style="text-align: center;">12/20/2018</td>
# <td style="text-align: center;">3/27/2019</td>
# <td style="text-align: center;">3/28/2019</td>
# <td style="text-align: center;">5/9/2019</td>
# <td style="text-align: center;">5/13/2019</td>
# <td style="text-align: center;">5/15/2019</td>
# <td style="text-align: center;">5/17/2019</td>
# <td style="text-align: center;">5/23/2019</td>
# </tr>
# <tr>
# <td style="text-align: center;">6/14/2019</td>
# <td style="text-align: center;">6/17/2019</td>
# <td style="text-align: center;">8/5/2019</td>
# <td style="text-align: center;">8/14/2019</td>
# <td style="text-align: center;">8/15/2019</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">1/23/2020</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">1/24/2020</td>
# <td style="text-align: center;">1/27/2020</td>
# <td style="text-align: center;">1/28/2020</td>
# <td style="text-align: center;">1/29/2020</td>
# </tr>
# <tr>
# <td style="text-align: center;">1/30/2020</td>
# <td style="text-align: center;">2/25/2020</td>
# <td style="text-align: center;">2/26/2020</td>
# <td style="text-align: center;">2/27/2020</td>
# <td style="text-align: center;">2/28/2020</td>
# <td style="text-align: center;">3/2/2020</td>
# <td style="text-align: center;">3/3/2020</td>
# <td style="text-align: center;">3/5/2020</td>
# <td style="text-align: center;">3/6/2020</td>
# <td style="text-align: center;">3/9/2020</td>
# </tr>
# <tr>
# <td style="background-color: #dbf9d6; font-weight: bold; text-align: center;">3/10/2020</td>
# <td style="background-color: #dbf9d6; font-weight: bold; text-align: center;">3/11/2020</td>
# <td style="background-color: #dbf9d6; font-weight: bold; text-align: center;">3/12/2020</td>
# <td style="background-color: #dbf9d6; font-weight: bold; text-align: center;">3/13/2020</td>
# <td style="background-color: #dbf9d6; font-weight: bold; text-align: center;">3/16/2020</td>
# <td style="background-color: #dbf9d6; font-weight: bold; text-align: center;">3/17/2020</td>
# <td style="background-color: #dbf9d6; font-weight: bold; text-align: center;">3/18/2020</td>
# <td style="background-color: #dbf9d6; font-weight: bold; text-align: center;">3/19/2020</td>
# <td style="text-align: center;">6/9/2021</td>
# <td style="text-align: center;">6/17/2021</td>
# </tr>
# <tr>
# <td style="text-align: center;">6/18/2021</td>
# <td style="text-align: center;">7/8/2021</td>
# <td style="text-align: center;">12/1/2021</td>
# <td style="text-align: center;">1/20/2022</td>
# <td style="text-align: center;">5/9/2022</td>
# <td style="text-align: center;">5/10/2022</td>
# <td style="text-align: center;">5/11/2022</td>
# <td style="text-align: center;">5/12/2022</td>
# <td style="text-align: center;">5/19/2022</td>
# <td style="background-color: #dbf9d6; font-weight: bold; text-align: center;">5/20/2022</td>
# </tr>
# <tr>
# <td style="text-align: center;">6/29/2022</td>
# <td style="text-align: center;">6/30/2022</td>
# <td style="background-color: #dbf9d6; font-weight: bold; text-align: center;">7/1/2022</td>
# <td style="background-color: #dbf9d6; font-weight: bold; text-align: center;">7/5/2022</td>
# <td style="text-align: center;">9/19/2022</td>
# <td style="text-align: center;">9/29/2022</td>
# <td style="text-align: center;">9/30/2022</td>
# <td style="text-align: center;">12/16/2022</td>
# <td style="text-align: center;">1/18/2023</td>
# <td style="text-align: center;">3/17/2023</td>
# </tr>
# <tr>
# <td style="text-align: center;">3/20/2023</td>
# <td style="text-align: center;">5/11/2023</td>
# <td style="text-align: center;">8/30/2023</td>
# <td style="text-align: center;">8/31/2023</td>
# <td style="text-align: center;">9/1/2023</td>
# <td style="text-align: center;">6/11/2024</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">6/12/2024</td>
# <td style="text-align: center;">6/13/2024</td>
# <td style="text-align: center;">6/14/2024</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">8/1/2024</td>
# </tr>
# <tr>
# <td style="text-align: center;">8/2/2024</td>
# <td style="text-align: center;">8/5/2024</td>
# <td style="text-align: center;">8/6/2024</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">11/27/2024</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">2/26/2025</td>
# <td style="text-align: center;">3/4/2025</td>
# <td style="text-align: center;">3/5/2025</td>
# <td style="text-align: center;">3/10/2025</td>
# <td style="text-align: center;">3/13/2025</td>
# <td style="text-align: center;">4/4/2025</td>
# </tr>
# <tr>
# <td style="text-align: center;">4/7/2025</td>
# <td style="text-align: center;">4/10/2025</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">10/10/2025</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">10/13/2025</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">10/14/2025</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">10/15/2025</td>
# <td style="text-align: center;">10/16/2025</td>
# <td style="text-align: center;">10/17/2025</td>
# <td style="text-align: center;">10/20/2025</td>
# <td style="text-align: center;">11/20/2025</td>
# </tr>
# <tr>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">11/21/2025</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">11/24/2025</td>
# <td style="background-color: #f08080; font-weight: bold; text-align: center;">11/25/2025</td>
# </tr>
# </table>

# %% [markdown]
# #### Band Expansion
# Widening Bollinger bandwidth reflects increased uncertainty in long-term inflation expectations. In the visual, periods where the bandwidth exceeds its moving average by a factor of 2x or more are shaded in light green, as doubling of the average bandwidth filters out everyday market noise and highlights significant chance in expectations. These periods are outlined below and contrasted against the average bandwidth:
#
# <table>
# <table border="1" style="text-align: center;">
#   <tr style="background-color: #dbf9db; color: black;">
#     <th>Period</th>
#     <th>Observations</th>
#     <th>Period Average Bandwidth</th>
#     <th>Overall Average Bandwidth</th>
#     <th>Delta</th>
#   </tr>
#   <tr>
#     <td>March 9th, 2020 - May 1st, 2020</td>
#     <td>40</td>
#     <td>1.06</td>
#     <td>0.24</td>
#     <td>0.82</td>
#   </tr>
#   <tr>
#     <td>October 26th, 2021 - October 29th, 2021</td>
#     <td>4</td>
#     <td>0.49</td>
#     <td>0.24</td>
#     <td>0.25</td>
#   </tr>
#   <tr>
#     <td>December 16th, 2021 - December 23rd, 2021</td>
#     <td>6</td>
#     <td>0.49</td>
#     <td>0.24</td>
#     <td>0.25</td>
#   </tr>
#   <tr>
#     <td>March 8th, 2022 - April 6th, 2022</td>
#     <td>22</td>
#     <td>0.69</td>
#     <td>0.24</td>
#     <td>0.44</td>
#   </tr>
#   <tr>
#     <td>May 20th, 2022 - June 3rd, 2022</td>
#     <td>11</td>
#     <td>0.55</td>
#     <td>0.24</td>
#     <td>0.31</td>
#   </tr>
#   <tr>
#     <td>July 1st, 2022 - July 26th, 2022</td>
#     <td>18</td>
#     <td>0.60</td>
#     <td>0.24</td>
#     <td>0.36</td>
#   </tr>
#   <tr>
#     <td>November 2nd, 2022 - November 10th, 2022</td>
#     <td>7</td>
#     <td>0.49</td>
#     <td>0.24</td>
#     <td>0.25</td>
#   </tr>
# </table>

# %% [markdown]
# #### Band Contraction
# Narrowing Bollinger bandwidth reflect market consensus and a consolidation of long-term inflation expectations. In the visual, periods where the bandwidth drops below its moving average by a factor of 0.5x or less are shared in light red, as halving of the average bandwidth filters out market noise and highlights significant compression in expectations. These periods are outlined below and contrasted against the average bandwidth:
#
# <table>
# <table border="1" style="text-align: center;">
#   <tr style="background-color: #f08080; color: black;">
#     <th>Period</th>
#     <th>Observations</th>
#     <th>Period Average Bandwidth</th>
#     <th>Overall Average Bandwidth</th>
#     <th>Delta</th>
#   </tr>
#   <tr>
#     <td>March 16th, 2018 - April 18th, 2018</td>
#     <td>24</td>
#     <td>0.10</td>
#     <td>0.24</td>
#     <td>-0.14</td>
#   </tr>
#   <tr>
#     <td>May 18th, 2018 - May 28th, 2018</td>
#     <td>7</td>
#     <td>0.08</td>
#     <td>0.24</td>
#     <td>-0.16</td>
#   </tr>
#   <tr>
#     <td>June 26th, 2018 - October 24th, 2018</td>
#     <td>87</td>
#     <td>0.08</td>
#     <td>0.24</td>
#     <td>-0.16</td>
#   </tr>
#   <tr>
#     <td>January 16th, 2020 - January 24th, 2020</td>
#     <td>7</td>
#     <td>0.09</td>
#     <td>0.24</td>
#     <td>-0.15</td>
#   </tr>
#   <tr>
#     <td>November 17th, 2020 - November 24th, 2020</td>
#     <td>6</td>
#     <td>0.12</td>
#     <td>0.24</td>
#     <td>-0.12</td>
#   </tr>
#   <tr>
#     <td>April 21st, 2021 - April 29th, 2021</td>
#     <td>7</td>
#     <td>0.11</td>
#     <td>0.24</td>
#     <td>-0.13</td>
#   </tr>
#   <tr>
#     <td>June 8th, 2023 - July 19th, 2023</td>
#     <td>30</td>
#     <td>0.11</td>
#     <td>0.24</td>
#     <td>-0.13</td>
#   </tr>
#   <tr>
#     <td>October 13th, 2023 - October 17th, 2023</td>
#     <td>3</td>
#     <td>0.11</td>
#     <td>0.24</td>
#     <td>-0.13</td>
#   </tr>
#   <tr>
#     <td>January 4th, 2024 - January 12th, 2024</td>
#     <td>7</td>
#     <td>0.11</td>
#     <td>0.24</td>
#     <td>-0.13</td>
#   </tr>
#   <tr>
#     <td>March 20th, 2024 - April 9th, 2024</td>
#     <td>15</td>
#     <td>0.09</td>
#     <td>0.24</td>
#     <td>-0.15</td>
#   </tr>
#   <tr>
#     <td>June 10th, 2024 - June 11th, 2024</td>
#     <td>2</td>
#     <td>0.10</td>
#     <td>0.24</td>
#     <td>-0.14</td>
#   </tr>
#   <tr>
#     <td>July 29th, 2024 - August 1st, 2024</td>
#     <td>4</td>
#     <td>0.11</td>
#     <td>0.24</td>
#     <td>-0.13</td>
#   </tr>
#   <tr>
#     <td>November 15th, 2024 - November 27th, 2024</td>
#     <td>9</td>
#     <td>0.11</td>
#     <td>0.24</td>
#     <td>-0.13</td>
#   </tr>
#   <tr>
#     <td>February 14th, 2025 - February 28th, 2025</td>
#     <td>11</td>
#     <td>0.09</td>
#     <td>0.24</td>
#     <td>-0.15</td>
#   </tr>
#   <tr>
#     <td>June 18th, 2025 - July 11th, 2025</td>
#     <td>18</td>
#     <td>0.10</td>
#     <td>0.24</td>
#     <td>-0.14</td>
#   </tr>
#   <tr>
#     <td>September 5th, 2025 - October 15th, 2025</td>
#     <td>29</td>
#     <td>0.10</td>
#     <td>0.24</td>
#     <td>-0.14</td>
#   </tr>
#   <tr>
#     <td>November 7th, 2025 - January 19th, 2026</td>
#     <td>52</td>
#     <td>0.08</td>
#     <td>0.24</td>
#     <td>-0.16</td>
#   </tr>
# </table>

# %% [markdown]
# #### Band Breach Trends
# Historical data shows an upward bias, with 146 upper band breaches outpacing the 113 lower band breaches. Most upper breaches occurred during 2021, while peak lower breaches clustered in 2018 and 2020. Current 2026 inflation expectations maintain this upward asymmetry, recording multiple upper band breaches and no lower band breaches.

# %% [markdown]
# #### Volatility and Band Breaches
# Breaches occur predominantly during periods of bandwidth compression. Contraction phases accounted for 24 upper and 22 lower breaches, whereas expansion phases accounted for only 5 upper and 11 lower breaches. These compressed regimes are statistically rare within the 2,160 days examined, with contractions spanning 318 (14.7%) and expansions spanning 108 days (5%).

# %% [markdown]
# #### Volatility Benchmarks
# Maximum Expansion: March 9th, 2020 - May 1st, 2020<br>
# Maximum Contraction: November 17th, 2020 - November 24th, 2020<br>
# Latest Expansion: November 2nd, 2022 - November 10th, 2022<br>
# Latest Contraction: November 7th, 2025 - January 19th, 2026<br>

# %% [markdown]
# #### What This Could Mean for the Future
# I believe the T10YIE is entering a transition phase based on patterns observed in the 10-Year Breakeven Inflation Rate with Bollinger Bands visual, and these patterns become clear when we contextualize them against similar geopolitical tensions. From mid 2023 through the first half of 2026, there have been eleven bandwidth contractions that have compressed volatility. When this holding pattern finally breaks, long-term inflation expectations will plummet. Given that the last true bandwidth expansion took place nearly four years ago in 2022 when energy costs began to drop back to pre-war levels, the prolonged absence of a major volatility cycle gives rise to a structural decline in inflation when the Iran War ends and gas prices fall once again. If a bandwidth expansion occurs, then lower band breaches may be more common than upper band breaches, as the daily rate would put downward pressure on widening the Bollinger Bands. This would mirror activity around March 8th to July 26th, 2022, when inflation expectations rose rapidly and dropped back down months later. It is possible that this holding pattern persists for longer than I anticipate, or it breaks and inflation expectations move higher; however, the historical context in which these events are playing out has me convinced that, when the Iran War ends and energy costs fall, downward pressure will push inflation expectations lower.

# %% [markdown]
# ### Rolling Correlation
# Rolling Correlation can measure the relationship between long-term inflation expectations and brent crude oil prices. This relationship is important, because energy costs are a determining factor in consumer prices. Tracking this relationship over a moving window reveals how strongly the global consumer’s outlook on inflation is impacted by oil price fluctuations.<br>
#
# A strong positive correlation (near 1.00) indicates that oil shocks are actively fueling inflation sentiment, driving T10YIE higher. Conversely, a negative correlation (approaching -1.00) implies an inverse relationship where an increase in energy prices is linked to a decline in long-term inflation expectations. A correlation close to zero suggests brent crude price fluctuations and market sentiment are moving independent of one another.
# <br><br>**Formula:**<br>
# To calculate the Rolling Correlation over a standard trading window, the Pearson correlation coefficient is computed iteratively for each data point using the trailing 252 days of data:
# $$\text{Rolling Correlation } (r) = \frac{\sum (X - \bar{X})(Y - \bar{Y})}{\sqrt{\sum (X - \bar{X})^2 \sum (Y - \bar{Y})^2}}$$
# * **$X$**: Daily Change in T10YIE Over a 252-Trading-Day Window
# * **$\bar{X}$**: Moving Average of $X$
# * **$Y$**: Daily Change in Brent Crude Oil Prices Over a 252-Trading-Day Window
# * **$\bar{Y}$**: Moving Average of $Y$
#
# <br>
# This window length was selected to smooth volatile spikes happening on a more granular, daily basis and to shorten windows to a year, as there are 252 trading days in one full year.

# %% [markdown]
# **Interpretation Guide**<br>
# The goal of using Rolling Correlation is to measure the strength and direction of the relationship between two assets over time, identifying when their connection tightens, decouples, or reverses. In the context of the 10-Year Breakeven Inflation Rate (T10YIE) and Brent Crude Oil Prices:<br>
#
# + When correlation approaches 1.00, the relationship is strongly positive, showing that rising oil prices are moving with higher inflation expectations.
# + When correlation approaches -1.00, the relationship becomes inverse, suggesting that spikes in energy costs could drag down long-term inflation sentiment.
# + Values near zero signal that brent crude prices and inflation expectations are moving independently without major influence on each other.

# %% [markdown]
# #### Setup Brent Crude Data and Merge

# %%
# Read in Brent Crude Data and Forward Fill Missing Data Points
df_brent = pd.read_excel('Data/DCOILBRENTEU.xlsx', sheet_name=1)
df_brent['DCOILBRENTEU'] = df_brent['DCOILBRENTEU'].ffill()
roll_corr = df[['observation_date','T10YIE']].merge(df_brent[['observation_date','DCOILBRENTEU']], on='observation_date', how='inner')
roll_corr.head()
# Out:
#   observation_date  T10YIE  DCOILBRENTEU
# 0       2018-02-05    2.10         67.69
# 1       2018-02-06    2.10         66.75
# 2       2018-02-07    2.10         65.74
# 3       2018-02-08    2.09         64.26
# 4       2018-02-09    2.05         63.04

# %% [markdown]
# #### Implementation and Visualization

# %%
# 252-Trading-Day Rolling Correlation
min_date = roll_corr['observation_date'].min()
max_date = roll_corr['observation_date'].max()
roll_corr['rolling_corr_252'] = roll_corr['T10YIE'].rolling(window=252).corr(roll_corr['DCOILBRENTEU'])
roll_corr['window'] = roll_corr.index // 252
roll_corr['overlap'] = np.where(
    (roll_corr['window'] > 0) & (roll_corr['window'] < 8) & (roll_corr.index % 252 > 0),
    roll_corr['window'] + 1, np.nan
)

# Long-Term Inflation Sentiment v. Brent Crude Oil Prices
plt.figure(figsize=(12, 5))
plt.margins(x=0.0001)
plt.grid(alpha=0.3, color='#000000', zorder=0)
plt.title('Rolling Correlation Between Inflation Sentiment and Brent Crude Oil', fontsize=12, fontweight='bold')
plt.axhline(0, color='grey', linestyle='--', zorder=2.5)
plt.ylabel('Correlation Coefficient', labelpad=15)
plt.xlabel('As of Date', labelpad=15)
plt.ylim(-1.05, 1.05)
plt.xlim(min_date, max_date)
plt.gca().tick_params(axis='x', labelsize=8)
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(bymonth=[1, 7]))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# Plot Correlation Line
plt.plot(
    roll_corr['observation_date'], roll_corr['rolling_corr_252'],
    label='252-Day Rolling Correlation', color='#6E4491', linewidth=1.5, zorder=3
)

# Shade Overlap Phase Background
unique_phases = sorted(roll_corr['overlap'].dropna().unique())
grey = np.linspace(0.95, 0.35, len(unique_phases))
for phase, shade in zip(unique_phases, grey):
    fltr = roll_corr['overlap'] == phase
    plt.fill_between(
        roll_corr['observation_date'], -1.05, 1.05,
        where=fltr, color=str(shade), alpha=0.6, zorder=1
    )

# Highlight Non-Overlap Phase Background
no_overlap = ((roll_corr['window'] > 0) & (roll_corr['window'] < 8) & (roll_corr.index % 252 == 0)) | (roll_corr['window'] == 8)
plt.fill_between(
    roll_corr['observation_date'], -1.05, 1.05,
    where=no_overlap, color='#FFC000', alpha=0.9, label='Non-Overlap', zorder=2
)

plt.legend(loc='lower right', fontsize=9, framealpha=0.9)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Interpretation
# Rolling Correlation shows long-term inflation and brent crude oil prices share a strong relationship, most of the time, when using standard trading day windows to measure co-movement from 2018 through 2026; though, before discussing the results in too much detail, it is important to call out a few points related to how this graph is structured:
# + First, the x-axis label "As of Date" is indicating that any given point on this chart reflects the cumulative statistical relationship across approximately one full trading year leading up to that date rather than a single day's market activity.
# <br><br>
# + Second, the background shading progressively moves from white to darker shades of grey as a subtle reminder that these phases are connected, because each daily correlation value shares up to 251 days with the previous phase.
# <br><br>
# + Third, the golden background indicates that there is no subsequent phase that overlaps with those observation dates and, in the case of the gold vertical lines, can highlight when a new phase starts.

# %% [markdown]
# Long-term inflation sentiment and brent crude oil prices are highly correlated. Across Rolling Correlation calculations, the relationship remained positive ~97% of the time, held at or above `0.7` for more than half of the observation period, and averaged `0.65`. The Rolling Correlation range peaked at `0.94` and dipped as low as `-0.06`. After hitting that minimum point around mid-2025, the correlation coefficient rebounded strongly into late 2025 before fluctuating in 2026. More recently, the relationship seems to be stabilizing around `0.5`.

# %% [markdown]
# #### Comparing Inflation Sentiment with Brent Crude Oil Prices
# For a closer look into how Long-Term Inflation Sentiment compares with daily Brent Crude Oil Prices, I plotted the two side-by-side. My hope in doing this is to show the directional alignment of these two macroeconomic indicators. Further, I believe this graph provides a deeper look into what correlation is actually capturing.

# %% [markdown]
# #### Implementation and Visualization

# %%
# Long-Term Inflation Sentiment v. Brent Crude Oil Prices
plt.figure(figsize=(12, 5))
plt.grid(alpha=0.3, color='#000000', zorder=0)
plt.title('Long-Term Inflation Sentiment v. Brent Crude Oil Prices', fontsize=12, fontweight='bold')
plt.ylabel('10Y Inflation Expectation (%)', labelpad=15)
plt.xlabel('Date', labelpad=15)
plt.ylim(0, 3.1)
plt.xlim(min_date, max_date)
plt.gca().tick_params(axis='x', labelsize=8)
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(bymonth=[1, 7]))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# Plot 10-Year Inflation Expectation (Left Axis)
line1 = plt.plot(
    roll_corr['observation_date'], roll_corr['T10YIE'], 
    color='#0073e6', linewidth=1.2, label='10-Year Inflation Expectation', zorder=2
)
plt.tick_params(axis='y', colors='#0073e6', labelsize=9)
for label in plt.gca().get_yticklabels():
    label.set_fontweight('bold')

# Plot Brent Crude Oil Price
plt.twinx()
line2 = plt.plot(
    roll_corr['observation_date'], roll_corr['DCOILBRENTEU'], 
    color='#DC143C', linewidth=1.2, label='Brent Crude Oil Price', zorder=3
)
plt.ylabel('Brent Crude Price ($)', labelpad=15)
plt.ylim(0, 140)
plt.tick_params(axis='y', colors='#DC143C', labelsize=9)
for label in plt.gca().get_yticklabels():
    label.set_fontweight('bold')

# Add Legend
lines = line1 + line2
labels = [l.get_label() for l in lines]
plt.legend(lines, labels, loc='lower right', fontsize=9, framealpha=0.9)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Interpretation
# This graph shows the co-movements of the 10-Year Breakeven Inflation Rate in blue and the Brent Crude Spot Price (pe) in red. These macroeconomic indicators are directionally aligned, barring a period from mid-2024 to early 2026 where oil prices fell while inflation sentiment rebounded in late 2024 following an initial dip. When oil spiked in early 2026, long-term inflation expectations rose only modestly relative to the surge in oil prices. Near the end of the chart, oil dropped rapidly from its peak of `$138.21` while inflation sentiment continued to rise only slightly. While inflation sentiment has remained sticky, neither increasing nor decreasing dramatically, the recent decline in oil prices suggests long-term inflation sentiment is due for a downward correction in the near term.

# %% [markdown]
# #### Historical Context
# The closing of the Strait of Hormuz caused the largest oil supply disruption in history, pushing the price per barrel to new heights observed on April 7th, 2026. Many believed the price would have risen higher, however, it reversed course and fell quickly due to the following reasons:
# <br><br>
# **Bypass Infrastructure**: Saudi Arabia expanded its Red Sea shipping capacity, while the United Arab Emirates increased its throughput with the Habshan-Fujairah pipeline to offset some of the loss in supply. Further, UAE abandoned OPEC, an organization that regulates oil production quotas, to capitalize on the regional disruption. Accordingly, the UAE is continuing to boost oil production into the foreseeable future.
# <br><br>
# **Emergency Supply**: The International Energy Agency (IEA) coordinated strategic reserve releases and the United States issued waivers authorizing the sale of Iranian and Russian oil that would have not been otherwise available. This allowed the oil market to benefit from a previously off limits supply.
# <br><br>
# **Demand Destruction**: The IEA reported that, “Oil demand is expected to contract by 80 kb/d this year, as the Iran war upends our global outlook. This is 730 kb/d less than in last month’s Report and a forecast 1.5 mb/d 2Q26 decline would be the sharpest since COVID-19 slashed fuel consumption.” This quote highlights how a significant supply disruption can cause oil demand to contract quickly.
# <br><br>
# **Oil Futures**: The market is pricing near-term contracts for barrels of oil significantly above those expected for delivery in 2027, which suggests the market expects that the oil supply disruptions will ease and conditions will improve. That is why I believe as oil prices moderate, long-term inflation sentiment will drop.

# %% [markdown]
# ### Seasonal Auto-Regressive Integrated Moving Average with Exogenous Regressor (SARIMAX) Model
# The SARIMAX model is a time-series forecasting method that combines historical patterns with external driver variables ($X_t$). In this case, 10-Year Breakeven Inflation Expectations (T10YIE) is modeled as the target variable ($y_t$), while brent crude oil prices (DCOILBRENTEU) serves as the exogenous factor ($X_t$). This allows the model to isolate how shifts in brent crude drive long-term inflation expectations through the remainder of 2026.
# <br><br>**Formula:**<br>
# $$y_t = \beta X_t + \frac{\theta(B)}{\phi(B)(1 - B)^d} \epsilon_t$$
#
# **Where:**
# * $y_t$: Expected Inflation Rate (`T10YIE`)
# * $\beta$: How Strongly Oil Prices Push or Pull Inflation
# * $X_t$: Brent Crude Oil Price in Europe (`DCOILBRENTEU`)
# * $\theta(B)$: Influence of Recent Unexpected Forecast Errors (shocks)
# * $\phi(B)$: Influence of Past Inflation Level (momentum)
# * $(1 - B)^d$: Adjustment Used to Remove Overall Trends and Keep Data Baseline Stable
# * $\epsilon_t$: Unexplained Market Noise & Non-Oil Factors (e.g. Interest Rates, Tariffs, Geopolitics, etc.)

# %% [markdown]
# **Interpretation Guide**<br>
# The SARIMAX model, like other regression forecasts, creates a linear relationship between a target variable and exogenous factors. In the context of this model, long-term inflation sentiment (T10YIE) is what's being predicted and crude oil price is the exogenous factor. An exogenous factor differs from a standard independent variable in that exogeneity has an element of directionality. The price of oil is a classic exogenous variable used to show its impact on inflation expectations, whereas inflation expectations don't directly force global oil prices higher or lower. Evidence of this is present in the graph "Long-Term Inflation Sentiment v. Brent Crude Oil Price," as oil prices are shown falling late 2024, meanwhile inflation sentiment rose. Oil falling through 2025 is shown to tug inflation sentiment back down. In calculating the future price of oil that is part of this forecast, I assumed oil would fall and that rate of change would be roughly similar to 90 days out from 2022's peak. I did this to get an average drop in the price of oil from a crisis that shares many similarities. Time will tell whether that was a fair assumption or not. Lastly, this forecast looks out to January 1st, 2027, or 165 observations, to estimate what the long-term inflation outlook looks like through the remainder of 2026.

# %% [markdown]
# #### Implementation and Visualization

# %%
# Fit SARIMAX Model on Full Historical Data with Brent Crude Oil Price Included as Exogenous Input
from statsmodels.tsa.statespace.sarimax import SARIMAX
sarimax_df = roll_corr.loc[:, ['observation_date', 'T10YIE', 'DCOILBRENTEU']]
model = SARIMAX(sarimax_df["T10YIE"], exog=sarimax_df[["DCOILBRENTEU"]])
model_fit = model.fit(disp=False)

# Create Future Dates & Exogenous Oil Trajectory Through End of Year (End Date: 1/1/2027)
forecast_steps = 165
last_date = sarimax_df["observation_date"].iloc[-1]
future_dates = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=forecast_steps, freq="B")

# Take Last Price of Oil and Apply Suspected Rate of Change
last_oil = sarimax_df["DCOILBRENTEU"].iloc[-1]
future_oil = [last_oil - 0.29 * (i + 1) for i in range(forecast_steps)]
exog_future = pd.DataFrame({"DCOILBRENTEU": future_oil}, index=future_dates)

# Generate Forecast
forecast = model_fit.forecast(steps=forecast_steps, exog=exog_future)

# Bring in Actual Observations from May 16th, 2026 - August 10th, 2026
actuals = pd.read_excel('Data/actuals.xlsx')
actuals['T10YIE'] = actuals['T10YIE'].ffill()

# Set Min/Max Date Boundaries
min_date = sarimax_df["observation_date"].min()
max_date = future_dates[-1]

# Create Graph with Semi-Annual X-axis Date Separation
plt.figure(figsize=(12, 5))
plt.grid(alpha=0.3, color="#000000", zorder=0)
plt.title("T10YIE Forecast Driven by Brent Crude Oil Pressure", fontsize=12, fontweight="bold")
plt.ylabel("10Y Inflation Expectation (%)", labelpad=15)
plt.xlabel("Date", labelpad=15)
plt.xlim(min_date, max_date)
plt.gca().tick_params(axis="x", labelsize=8)
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(bymonth=[1, 7]))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))

# Plot Historical Inflation
plt.plot(sarimax_df["observation_date"], sarimax_df["T10YIE"], color="#0073e6", linewidth=1.2, label="Historical T10YIE", zorder=2)

# Plot Forecast Trajectory
plt.plot(future_dates, forecast, color="#DC143C", linewidth=1.8, linestyle="--", label="T10YIE Forecast", zorder=2)

# Plot Actual Observations
plt.plot(actuals["observation_date"], actuals["T10YIE"], color="#2ca02c", linewidth=1.5, label="Actual T10YIE", zorder=3)

plt.legend(loc="lower right", fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Interpretation
# This chart illustrates the historical 10-Year Breakeven Inflation Rate, alongside a SARIMAX forecast. To evaluate model performance, actual T10YIE values are included through January 1st, 2027. Following May 15th, 2026 long-term inflation sentiment experienced a sharp decline, suspected to be driven by promises of a deal regarding the Iran War. While a pullback in inflation expectations was anticipated, the velocity and magnitude of this drop exceeded model projections. This sharper decline may reflect, among other factors, accelerated demand destruction for crude oil, materializing labor market weakness, or broader geopolitical relationships being tested. Ultimately, I believe long-term inflation sentiment points towards inflation falling back to 2%, with T10YIE forecasted to be at 2.2% on January 1st, 2027.

# %% [markdown]
# ## Conclusion and Implications

# %% [markdown]
# ### Analytical Summary
# + Bullet
#
# + Bullet
#
# + Bullet
#
# + Bullet
#
# + Bullet

# %% [markdown]
# ### Final Takeaway
# ....

# %% [markdown]
# ## Sources

# %% [markdown]
# +
#
# +
#
# +
